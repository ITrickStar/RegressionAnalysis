# %%
import pandas as pd;
import numpy as np;
import matplotlib.pyplot as plt;
import seaborn as sns;

dataset_raw = pd.read_excel('apartment_data.xlsx', usecols=lambda x: 'Unnamed' not in x, skiprows=1);

# %% [markdown]
# Загрузим данные о ценах на нижегородские квартиры. Для работы с таблицей будем использовать программная библиотеку языка Python для обработки и анализа данных pandas.

# %%
print(dataset_raw.shape[0], " - число объектов");
print(dataset_raw.shape[1]-1, " - число признаков");
print(dataset_raw.head());
# Out:
# 2600  - число объектов
# 30  - число признаков
#    Тип рынка              Функциональная зона  Общая площадь,\nкв.м  \
# 0  Вторичный  Многоквартирная жилая застройка             45.700001
# 1  Вторичный  Многоквартирная жилая застройка             38.099998
# 2  Вторичный  Многоквартирная жилая застройка             53.400002
# 3  Вторичный  Многоквартирная жилая застройка             56.000000
# 4  Вторичный  Многоквартирная жилая застройка             43.000000
#
#    Жилая площадь,\nкв.м  Площадь кухни,\nкв.м  Высота потолков, м  \
# 0             27.299999                   7.0                 NaN
# 1             22.700001                   7.0                 NaN
# 2             25.000000                  14.0                 NaN
# 3             33.200001                   8.6                 NaN
# 4             19.000000                  12.0                 NaN
#
#    Год постройки                   Тип дома   Класс  Этаж  ...  \
# 0           1975   Советская более 5 этажей  Эконом     8  ...
# 1           1974   Советская более 5 этажей  Эконом     4  ...
# 2           2007                Современные  Эконом     2  ...
# 3           1958  Советская до 5 этажей вкл  Эконом     5  ...
# 4           2009                Современные  Эконом     1  ...
#
#    Дата снятия (продажи) Актуальность на дату послед. проверки  \
# 0             19.09.2022                                 Снято
# 1                    NaN                             Актуально
# 2                    NaN                             Актуально
# 3                    NaN                             Актуально
# 4             19.09.2022                                 Снято
#
#   Колич.  Просмотр. Колич.  Просм. в день Остановка\nм Парк\nм  Центр\nкм  \
# 0                 7                  0.29          168     921         13
# 1                 8                  0.25          401     426         10
# 2                 7                  0.29          215     406          2
# 3                 9                  0.22          161     974          9
# 4                 6                  0.33          292     529         10
#
#    Станция метро\nм Школа\nм Детский сад\nм
# 0              6065    148.0          161.0
# 1               935    386.0          217.0
# 2              1605    412.0          336.0
# 3               165    306.0           47.0
# 4              3011    550.0          238.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Таблица содержит данные о 2600 квартир, выставленных на продажу в г.Нижнем Новгороде. Данные о каждой квартире характеризуют 30 признаков, включающих: цену (в руб.), удаленность от других объектов инфраструктуры, рынка (вторичка или новостройка), количество этажей, тип дома, количество комнат, номер этажа и общая площадь квартиры (в кв.м).

# %%
for i in range(1, dataset_raw.columns.size):
    col = str(i)+') '+dataset_raw.columns[i].replace('\n', ' ');
    print(col);
# Out:
# 1) Функциональная зона
# 2) Общая площадь, кв.м
# 3) Жилая площадь, кв.м
# 4) Площадь кухни, кв.м
# 5) Высота потолков, м
# 6) Год постройки
# 7) Тип дома
# 8) Класс
# 9) Этаж
# 10) Этажность
# 11) Тип этажа
# 12) Состояние ремонта
# 13) Количество комнат
# 14) Парковка
# 15) Материал стен
# 16) Цена предложения, руб.
# 17) Удельная цена, руб./кв.м
# 18) Дата создания
# 19) Дата парсинга
# 20) Дата послед. проверки
# 21) Дата снятия (продажи)
# 22) Актуальность на дату послед. проверки
# 23) Колич.  Просмотр.
# 24) Колич.  Просм. в день
# 25) Остановка м
# 26) Парк м
# 27) Центр км
# 28) Станция метро м
# 29) Школа м
# 30) Детский сад м

# %% [markdown]
# Среди качественных признаков можно выделить:
# 1. *Бинарные* - Тип рынка;
# 2. *Категориальные*(*Факторные*) - все остальные;

# %%
dataset_raw.describe(include=['object'])
# Out:
#        Общая площадь,\nкв.м  Жилая площадь,\nкв.м  Площадь кухни,\nкв.м  \
# count           2600.000000           2600.000000           2600.000000
# mean              51.142385             30.031808              8.735500
# std               26.735726             15.717637              4.639916
# min               13.400000              7.200000              3.000000
# 25%               35.000000             18.100000              6.000000
# 50%               45.000000             28.000000              7.000000
# 75%               60.000000             38.000000             10.000000
# max              611.000000            200.000000             60.000000
#
#        Высота потолков, м  Год постройки         Этаж    Этажность  \
# count          300.000000    2600.000000  2600.000000  2572.000000
# mean             2.567000    1982.953462     5.168462     8.529160
# std              0.113963      22.679368     4.293763     4.588844
# min              2.000000    1916.000000     1.000000     1.000000
# 25%              2.500000    1967.000000     2.000000     5.000000
# 50%              2.500000    1977.000000     4.000000     9.000000
# 75%              2.700000    2000.000000     7.000000    10.000000
# max              3.000000    2024.000000    25.000000    27.000000
#
#        Цена предложения,\nруб.  Удельная цена, руб./кв.м  Колич.  Просмотр.  \
# count             2.600000e+03               2600.000000         2600.00000
# mean              6.351669e+06             123348.136538           26.43500
# std               4.142744e+06              36737.216399           24.62378
# min               1.000000e+06              13750.000000            1.00000
# 25%               4.000000e+06              99426.250000            7.00000
# 50%               5.200000e+06             114991.500000           26.00000
# 75%               7.202500e+06             139155.250000           35.00000
# max               6.100000e+07             397589.000000          369.00000
#
#        Колич.  Просм. в день  Остановка\nм      Парк\nм    Центр\nкм  \
# count            2600.000000   2600.000000  2600.000000  2600.000000
# mean                0.304815    259.069615   748.081923     8.088462
# std                 0.877778    218.972639   560.165029     4.008919
# min                 0.000000      0.000000    43.000000     0.000000
# 25%                 0.020000    124.000000   328.000000     5.000000
# 50%                 0.050000    199.000000   610.000000     8.000000
# 75%                 0.250000    304.000000  1019.000000    11.000000
# max                20.000000   1252.000000  4963.000000    19.000000
#
#        Станция метро\nм     Школа\nм  Детский сад\nм
# count       2600.000000  2467.000000     2467.000000
# mean        2638.335385   382.493312      321.945683
# std         1934.772706   331.048900      293.858959
# min           29.000000    43.000000       29.000000
# 25%         1057.500000   197.000000      151.000000
# 50%         1967.000000   301.000000      244.000000
# 75%         4276.250000   446.000000      386.000000
# max        11760.000000  3530.000000     4369.000000

# %% [markdown]
# Количественные признаки представляют собой непрерывные числовые величины.

# %%
dataset_raw.describe(include=['number'])
# Out:
#        Общая площадь,\nкв.м  Жилая площадь,\nкв.м  Площадь кухни,\nкв.м  \
# count           2600.000000           2600.000000           2600.000000
# mean              51.142385             30.031808              8.735500
# std               26.735726             15.717637              4.639916
# min               13.400000              7.200000              3.000000
# 25%               35.000000             18.100000              6.000000
# 50%               45.000000             28.000000              7.000000
# 75%               60.000000             38.000000             10.000000
# max              611.000000            200.000000             60.000000
#
#        Высота потолков, м  Год постройки         Этаж    Этажность  \
# count          300.000000    2600.000000  2600.000000  2572.000000
# mean             2.567000    1982.953462     5.168462     8.529160
# std              0.113963      22.679368     4.293763     4.588844
# min              2.000000    1916.000000     1.000000     1.000000
# 25%              2.500000    1967.000000     2.000000     5.000000
# 50%              2.500000    1977.000000     4.000000     9.000000
# 75%              2.700000    2000.000000     7.000000    10.000000
# max              3.000000    2024.000000    25.000000    27.000000
#
#        Цена предложения,\nруб.  Удельная цена, руб./кв.м  Колич.  Просмотр.  \
# count             2.600000e+03               2600.000000         2600.00000
# mean              6.351669e+06             123348.136538           26.43500
# std               4.142744e+06              36737.216399           24.62378
# min               1.000000e+06              13750.000000            1.00000
# 25%               4.000000e+06              99426.250000            7.00000
# 50%               5.200000e+06             114991.500000           26.00000
# 75%               7.202500e+06             139155.250000           35.00000
# max               6.100000e+07             397589.000000          369.00000
#
#        Колич.  Просм. в день  Остановка\nм      Парк\nм    Центр\nкм  \
# count            2600.000000   2600.000000  2600.000000  2600.000000
# mean                0.304815    259.069615   748.081923     8.088462
# std                 0.877778    218.972639   560.165029     4.008919
# min                 0.000000      0.000000    43.000000     0.000000
# 25%                 0.020000    124.000000   328.000000     5.000000
# 50%                 0.050000    199.000000   610.000000     8.000000
# 75%                 0.250000    304.000000  1019.000000    11.000000
# max                20.000000   1252.000000  4963.000000    19.000000
#
#        Станция метро\nм     Школа\nм  Детский сад\nм
# count       2600.000000  2467.000000     2467.000000
# mean        2638.335385   382.493312      321.945683
# std         1934.772706   331.048900      293.858959
# min           29.000000    43.000000       29.000000
# 25%         1057.500000   197.000000      151.000000
# 50%         1967.000000   301.000000      244.000000
# 75%         4276.250000   446.000000      386.000000
# max        11760.000000  3530.000000     4369.000000

# %% [markdown]
# Перед тем как взаимодействовать с данными нам необходимо их подготовить - убрать пропущенные значения, очистить от выбросов.

# %% [markdown]
# Сначала необходимо узнать количество пропущенных значений в каждом из столбцов:

# %%
print(dataset_raw.isnull().sum());
# Out:
# Тип рынка                                   0
# Функциональная зона                         0
# Общая площадь,\nкв.м                        0
# Жилая площадь,\nкв.м                        0
# Площадь кухни,\nкв.м                        0
# Высота потолков, м                       2300
# Год постройки                               0
# Тип дома                                    0
# Класс                                       0
# Этаж                                        0
# Этажность                                  28
# Тип этажа                                 107
# Состояние ремонта                        1583
# Количество комнат                           0
# Парковка                                    0
# Материал стен                               0
# Цена предложения,\nруб.                     0
# Удельная цена, руб./кв.м                    0
# Дата создания                               0
# Дата парсинга                               0
# Дата послед. проверки                       0
# Дата снятия (продажи)                    1351
# Актуальность на дату послед. проверки       0
# Колич.  Просмотр.                           0
# Колич.  Просм. в день                       0
# Остановка\nм                                0
# Парк\nм                                     0
# Центр\nкм                                   0
# Станция метро\nм                            0
# Школа\nм                                  133
# Детский сад\nм                            133
# dtype: int64

# %% [markdown]
# Признаки, по которым количество пропущенных значений составляет ~1%, можно убрать из таблицы (```"Этажность"```).<br>
# Можно заметить, что в некоторых столбцах значения заведомо оставлены пустыми, например ```"Высота потолков"``` - 2300/2600, для этого параметра я указал среднее значение по СП. Для таких параметров как ```"Состояние ремонта"``` и ```"Дата снятия (продажи)"``` указать среднее значение не получится, их следует просто заполнить пустыми константами np.nan.<br>
# Признак ```"Количество комнат"``` мы ранее причислили к качественным, что не совсем верно. Нам следует заменить значение ```"Студия"``` на ```float(0)```, чтобы определить признак в дискретные числовые величины.<br>
# Для числовых параметров удобно использовать медиану для заполнения пропущенных элементов (```"Школа м"```, ```"Детский сад м"```), а для качественных - моду (```"Тип этажа"```).

# %%
for i in range(dataset_raw.columns.size):
    if(dataset_raw[dataset_raw.columns[i]].isnull().sum() and float(dataset_raw[dataset_raw.columns[i]].isnull().sum()) < dataset_raw.shape[0]/90):
        dataset_raw.dropna(subset=[dataset_raw.columns[i]], inplace=True)

dataset_raw["Высота потолков, м"].fillna(2.65, inplace=True)
dataset_raw["Тип этажа"].fillna(dataset_raw["Тип этажа"].mode().iloc[0], inplace=True)
dataset_raw["Состояние ремонта"].fillna(np.nan, inplace=True)
dataset_raw.loc[dataset_raw["Количество комнат"] == "Студия", "Количество комнат"] = 0
dataset_raw["Дата снятия (продажи)"].fillna(np.nan, inplace=True)
dataset_raw["Школа\nм"].fillna(dataset_raw["Школа\nм"].median(axis = 0), inplace=True)
dataset_raw["Детский сад\nм"].fillna(dataset_raw["Детский сад\nм"].median(axis = 0), inplace=True)

# %% [markdown]
# Таким образом получим данные без пропущенных элементов:

# %%
print(dataset_raw.isnull().sum());
# Out:
# Тип рынка                                   0
# Функциональная зона                         0
# Общая площадь,\nкв.м                        0
# Жилая площадь,\nкв.м                        0
# Площадь кухни,\nкв.м                        0
# Высота потолков, м                          0
# Год постройки                               0
# Тип дома                                    0
# Класс                                       0
# Этаж                                        0
# Этажность                                   0
# Тип этажа                                   0
# Состояние ремонта                        1568
# Количество комнат                           0
# Парковка                                    0
# Материал стен                               0
# Цена предложения,\nруб.                     0
# Удельная цена, руб./кв.м                    0
# Дата создания                               0
# Дата парсинга                               0
# Дата послед. проверки                       0
# Дата снятия (продажи)                    1339
# Актуальность на дату послед. проверки       0
# Колич.  Просмотр.                           0
# Колич.  Просм. в день                       0
# Остановка\nм                                0
# Парк\nм                                     0
# Центр\nкм                                   0
# Станция метро\nм                            0
# Школа\nм                                    0
# Детский сад\nм                              0
# dtype: int64

# %% [markdown]
# Перейдем к очистке данных от выбросов. Для этого уберем параметры выходящие за квантиль 0.005 и 0.995 соответственно, таким образом мы уберем данных выходящие за пределы 99% всех значений. Хотя визуально представленные графики не отличаются, значения у них различны, что видно при выводе в консоль

# %%
dataset_raw.head()
# Out:
#    Тип рынка              Функциональная зона  Общая площадь,\nкв.м  \
# 0  Вторичный  Многоквартирная жилая застройка             45.700001
# 1  Вторичный  Многоквартирная жилая застройка             38.099998
# 2  Вторичный  Многоквартирная жилая застройка             53.400002
# 3  Вторичный  Многоквартирная жилая застройка             56.000000
# 4  Вторичный  Многоквартирная жилая застройка             43.000000
#
#    Жилая площадь,\nкв.м  Площадь кухни,\nкв.м  Высота потолков, м  \
# 0             27.299999                   7.0                2.65
# 1             22.700001                   7.0                2.65
# 2             25.000000                  14.0                2.65
# 3             33.200001                   8.6                2.65
# 4             19.000000                  12.0                2.65
#
#    Год постройки                   Тип дома   Класс  Этаж  ...  \
# 0           1975   Советская более 5 этажей  Эконом     8  ...
# 1           1974   Советская более 5 этажей  Эконом     4  ...
# 2           2007                Современные  Эконом     2  ...
# 3           1958  Советская до 5 этажей вкл  Эконом     5  ...
# 4           2009                Современные  Эконом     1  ...
#
#    Дата снятия (продажи) Актуальность на дату послед. проверки  \
# 0             19.09.2022                                 Снято
# 1                    NaN                             Актуально
# 2                    NaN                             Актуально
# 3                    NaN                             Актуально
# 4             19.09.2022                                 Снято
#
#   Колич.  Просмотр. Колич.  Просм. в день Остановка\nм Парк\nм  Центр\nкм  \
# 0                 7                  0.29          168     921         13
# 1                 8                  0.25          401     426         10
# 2                 7                  0.29          215     406          2
# 3                 9                  0.22          161     974          9
# 4                 6                  0.33          292     529         10
#
#    Станция метро\nм Школа\nм Детский сад\nм
# 0              6065    148.0          161.0
# 1               935    386.0          217.0
# 2              1605    412.0          336.0
# 3               165    306.0           47.0
# 4              3011    550.0          238.0
#
# [5 rows x 31 columns]

# %%
print(dataset_raw.shape[0], end='->');
numdata = dataset_raw.select_dtypes(include=["number"]);
for i in range(numdata.columns.size):
    dataset = dataset_raw[
    (dataset_raw[numdata.columns[i]] >= dataset_raw[numdata.columns[i]].quantile(0.05)) & (dataset_raw[numdata.columns[i]] <= dataset_raw[numdata.columns[i]].quantile(0.95))];
print(dataset.shape[0]);

dataset.head()
# Out:
# 2572->2318
#    Тип рынка              Функциональная зона  Общая площадь,\nкв.м  \
# 0  Вторичный  Многоквартирная жилая застройка             45.700001
# 1  Вторичный  Многоквартирная жилая застройка             38.099998
# 2  Вторичный  Многоквартирная жилая застройка             53.400002
# 4  Вторичный  Многоквартирная жилая застройка             43.000000
# 5  Вторичный  Многоквартирная жилая застройка             58.000000
#
#    Жилая площадь,\nкв.м  Площадь кухни,\nкв.м  Высота потолков, м  \
# 0             27.299999                   7.0                2.65
# 1             22.700001                   7.0                2.65
# 2             25.000000                  14.0                2.65
# 4             19.000000                  12.0                2.65
# 5             41.000000                   6.0                2.65
#
#    Год постройки                   Тип дома   Класс  Этаж  ...  \
# 0           1975   Советская более 5 этажей  Эконом     8  ...
# 1           1974   Советская более 5 этажей  Эконом     4  ...
# 2           2007                Современные  Эконом     2  ...
# 4           2009                Современные  Эконом     1  ...
# 5           1977  Советская до 5 этажей вкл  Эконом     3  ...
#
#    Дата снятия (продажи) Актуальность на дату послед. проверки  \
# 0             19.09.2022                                 Снято
# 1                    NaN                             Актуально
# 2                    NaN                             Актуально
# 4             19.09.2022                                 Снято
# 5                    NaN                             Актуально
#
#   Колич.  Просмотр. Колич.  Просм. в день Остановка\nм Парк\nм  Центр\nкм  \
# 0                 7                  0.29          168     921         13
# 1                 8                  0.25          401     426         10
# 2                 7                  0.29          215     406          2
# 4                 6                  0.33          292     529         10
# 5                16                  0.12          257     328         10
#
#    Станция метро\nм Школа\nм Детский сад\nм
# 0              6065    148.0          161.0
# 1               935    386.0          217.0
# 2              1605    412.0          336.0
# 4              3011    550.0          238.0
# 5              1537    446.0          104.0
#
# [5 rows x 31 columns]

# %% [markdown]
# Перейдем к общему графическому предствлению данных.</b>
# Ниже при помощи гистограммы представлено распределение значений ```"Цены предложения"``` на указанном графике.

# %%
sns.displot(dataset["Цена предложения,\nруб."], bins=15, kde=True);
plt.grid();

# %% [markdown]
# Составим распределение для всех признаков:

# %%
#pd.plotting.scatter_matrix(dataset, figsize=(10,8))

# %%
#pd.plotting.hist_frame(dataset, figsize=(10,8))

# %% [markdown]
# Рассмотрим графики зависимости параметров относительно ключевого признака ```"Цены предложения"```.

# %%
for i in range(dataset.columns.size):
    sns.jointplot(x="Цена предложения,\nруб.", y=dataset.columns[i], alpha=.40, data=dataset);
# Out:
# C:\Users\anoni\AppData\Roaming\Python\Python37\site-packages\seaborn\axisgrid.py:1690: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   f = plt.figure(figsize=(height, height))

# %%
# pd.plotting.scatter_matrix(dataset_raw, figsize=(10,8))

# %%
corr_mat = dataset.corr();
print(corr_mat);
sns.heatmap(corr_mat, vmin=-1, vmax=1, square=True, cmap='coolwarm')
#sns.heatmap(corr_mat, square=True, annot=True, fmt='.2f', vmin=-1, vmax=1, cmap='coolwarm');
# Out:
#                           Общая площадь,\nкв.м  Жилая площадь,\nкв.м  \
# Общая площадь,\nкв.м                  1.000000              0.935274
# Жилая площадь,\nкв.м                  0.935274              1.000000
# Площадь кухни,\nкв.м                  0.621852              0.384741
# Высота потолков, м                    0.005678              0.075840
# Год постройки                         0.261093              0.055961
# Этаж                                  0.117758             -0.007148
# Этажность                             0.169387             -0.012302
# Цена предложения,\nруб.               0.815465              0.712571
# Удельная цена, руб./кв.м              0.069030             -0.049981
# Колич.  Просмотр.                     0.004546             -0.001735
# Колич.  Просм. в день                -0.039920             -0.028215
# Остановка\nм                          0.085808             -0.012170
# Парк\nм                              -0.028241             -0.092814
# Центр\nкм                            -0.220851             -0.188799
# Станция метро\nм                      0.015843             -0.064390
# Школа\nм                              0.009190             -0.042975
# Детский сад\nм                        0.015838             -0.038064
#
#                           Площадь кухни,\nкв.м  Высота потолков, м  \
# Общая площадь,\nкв.м                  0.621852            0.005678
# Жилая площадь,\nкв.м                  0.384741            0.075840
# Площадь кухни,\nкв.м                  1.000000           -0.218446
# Высота потолков, м                   -0.218446            1.000000
# Год постройки                         0.568896           -0.264566
# Этаж                                  0.360481           -0.201303
# Этажность                             0.466337           -0.168034
# Цена предложения,\nруб.               0.663102           -0.037414
# Удельная цена, руб./кв.м              0.317825           -0.145304
# Колич.  Просмотр.                     0.026762           -0.026264
# Колич.  Просм. в день                -0.058265            0.043036
# Остановка\nм                          0.302923           -0.460790
# Парк\nм                               0.143371           -0.190496
# Центр\nкм                            -0.181874           -0.019043
# Станция метро\nм                      0.211851           -0.266936
# Школа\nм                              0.101440           -0.009259
# Детский сад\nм                        0.087928           -0.002667
#
#                           Год постройки      Этаж  Этажность  \
# Общая площадь,\nкв.м           0.261093  0.117758   0.169387
# Жилая площадь,\nкв.м           0.055961 -0.007148  -0.012302
# Площадь кухни,\nкв.м           0.568896  0.360481   0.466337
# Высота потолков, м            -0.264566 -0.201303  -0.168034
# Год постройки                  1.000000  0.534673   0.781654
# Этаж                           0.534673  1.000000   0.638349
# Этажность                      0.781654  0.638349   1.000000
# Цена предложения,\nруб.        0.385109  0.214437   0.295526
# Удельная цена, руб./кв.м       0.403917  0.297468   0.408290
# Колич.  Просмотр.              0.034039  0.028270   0.014473
# Колич.  Просм. в день         -0.042494 -0.028292  -0.042724
# Остановка\nм                   0.412612  0.234571   0.279195
# Парк\nм                        0.308829  0.215622   0.282463
# Центр\nкм                     -0.073980  0.028863  -0.021831
# Станция метро\nм               0.365882  0.203465   0.224521
# Школа\nм                       0.233413  0.128642   0.208647
# Детский сад\nм                 0.191572  0.056593   0.142787
#
#                           Цена предложения,\nруб.  Удельная цена, руб./кв.м  \
# Общая площадь,\nкв.м                     0.815465                  0.069030
# Жилая площадь,\nкв.м                     0.712571                 -0.049981
# Площадь кухни,\nкв.м                     0.663102                  0.317825
# Высота потолков, м                      -0.037414                 -0.145304
# Год постройки                            0.385109                  0.403917
# Этаж                                     0.214437                  0.297468
# Этажность                                0.295526                  0.408290
# Цена предложения,\nруб.                  1.000000                  0.558213
# Удельная цена, руб./кв.м                 0.558213                  1.000000
# Колич.  Просмотр.                        0.021859                  0.037765
# Колич.  Просм. в день                   -0.065007                 -0.062733
# Остановка\nм                             0.122975                  0.135098
# Парк\nм                                 -0.031840                  0.015242
# Центр\nкм                               -0.326797                 -0.319085
# Станция метро\nм                         0.023470                  0.053174
# Школа\nм                                 0.018661                  0.036062
# Детский сад\nм                           0.080819                  0.150650
#
#                           Колич.  Просмотр.  Колич.  Просм. в день  \
# Общая площадь,\nкв.м               0.004546              -0.039920
# Жилая площадь,\nкв.м              -0.001735              -0.028215
# Площадь кухни,\nкв.м               0.026762              -0.058265
# Высота потолков, м                -0.026264               0.043036
# Год постройки                      0.034039              -0.042494
# Этаж                               0.028270              -0.028292
# Этажность                          0.014473              -0.042724
# Цена предложения,\nруб.            0.021859              -0.065007
# Удельная цена, руб./кв.м           0.037765              -0.062733
# Колич.  Просмотр.                  1.000000              -0.157910
# Колич.  Просм. в день             -0.157910               1.000000
# Остановка\nм                       0.026176              -0.048480
# Парк\nм                           -0.012561              -0.038205
# Центр\nкм                          0.039695               0.006454
# Станция метро\nм                  -0.005719              -0.046925
# Школа\nм                           0.005941              -0.018650
# Детский сад\nм                     0.010058               0.017923
#
#                           Остановка\nм   Парк\nм  Центр\nкм  Станция метро\nм  \
# Общая площадь,\nкв.м          0.085808 -0.028241  -0.220851          0.015843
# Жилая площадь,\nкв.м         -0.012170 -0.092814  -0.188799         -0.064390
# Площадь кухни,\nкв.м          0.302923  0.143371  -0.181874          0.211851
# Высота потолков, м           -0.460790 -0.190496  -0.019043         -0.266936
# Год постройки                 0.412612  0.308829  -0.073980          0.365882
# Этаж                          0.234571  0.215622   0.028863          0.203465
# Этажность                     0.279195  0.282463  -0.021831          0.224521
# Цена предложения,\nруб.       0.122975 -0.031840  -0.326797          0.023470
# Удельная цена, руб./кв.м      0.135098  0.015242  -0.319085          0.053174
# Колич.  Просмотр.             0.026176 -0.012561   0.039695         -0.005719
# Колич.  Просм. в день        -0.048480 -0.038205   0.006454         -0.046925
# Остановка\nм                  1.000000  0.317158  -0.022934          0.353725
# Парк\nм                       0.317158  1.000000   0.161746          0.452013
# Центр\nкм                    -0.022934  0.161746   1.000000          0.112380
# Станция метро\nм              0.353725  0.452013   0.112380          1.000000
# Школа\nм                      0.171533  0.252320   0.056659          0.271612
# Детский сад\nм                0.082223 -0.011021  -0.220536          0.058171
#
#                           Школа\nм  Детский сад\nм
# Общая площадь,\nкв.м      0.009190        0.015838
# Жилая площадь,\nкв.м     -0.042975       -0.038064
# Площадь кухни,\nкв.м      0.101440        0.087928
# Высота потолков, м       -0.009259       -0.002667
# Год постройки             0.233413        0.191572
# Этаж                      0.128642        0.056593
# Этажность                 0.208647        0.142787
# Цена предложения,\nруб.   0.018661        0.080819
# Удельная цена, руб./кв.м  0.036062        0.150650
# Колич.  Просмотр.         0.005941        0.010058
# Колич.  Просм. в день    -0.018650        0.017923
# Остановка\nм              0.171533        0.082223
# Парк\nм                   0.252320       -0.011021
# Центр\nкм                 0.056659       -0.220536
# Станция метро\nм          0.271612        0.058171
# Школа\nм                  1.000000        0.227881
# Детский сад\nм            0.227881        1.000000
# <AxesSubplot:>

# %% [markdown]
# Выведем коэффициенты корреляции, больше заданного значения:

# %%
corr_mat['Цена предложения,\nруб.'].where(corr_mat['Цена предложения,\nруб.']>0.3)
# Out:
# Общая площадь,\nкв.м        0.815465
# Жилая площадь,\nкв.м        0.712571
# Площадь кухни,\nкв.м        0.663102
# Высота потолков, м               NaN
# Год постройки               0.385109
# Этаж                             NaN
# Этажность                        NaN
# Цена предложения,\nруб.     1.000000
# Удельная цена, руб./кв.м    0.558213
# Колич.  Просмотр.                NaN
# Колич.  Просм. в день            NaN
# Остановка\nм                     NaN
# Парк\nм                          NaN
# Центр\nкм                        NaN
# Станция метро\nм                 NaN
# Школа\nм                         NaN
# Детский сад\nм                   NaN
# Name: Цена предложения,\nруб., dtype: float64

# %% [markdown]
# Следующие параметры больше других влияют на окончательную стоимость квартиры:
# 1. ```Общая площадь, м```
# 2. ```Жилая площадь, кв.м```
# 3. ```Площадь кухни, кв.м```
# 4. ```Год постройки```
